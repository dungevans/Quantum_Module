# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import string
import pickle

from tqdm import tqdm
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch.utils.data import Dataset, DataLoader, ConcatDataset

# %%
num_epochs = 10
batch_size = 32
learning_rate = 0.00001
momentum = 0.9

# %%
ALPHABET = string.ascii_lowercase + string.digits + "."
char2idx = {c: i + 1 for i, c in enumerate(ALPHABET)}  # padding=0
idx2char = {i: c for c, i in char2idx.items()}  # Reverse mapping index -> character
vocab_size = len(char2idx) + 1

MAX_LEN = 50


def domain_to_tensor(domain):
    arr = [char2idx.get(c, 0) for c in domain.lower()][:MAX_LEN]
    arr += [0] * (MAX_LEN - len(arr))
    return torch.tensor(arr, dtype=torch.long)


def tensor_to_domain(tensor):
    domain = "".join(idx2char.get(idx, "") for idx in tensor.tolist() if idx > 0)  # Ignore padding (0)
    return domain


def load_dataset(file_path):
    with open(file_path, 'rb') as file:
        dataloader = pickle.load(file)
    print(f"DataLoader loaded from {file_path}.")
    return dataloader


class DomainDataset(Dataset):
    def __init__(self, samples):
        self.samples = samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        dom, lbl = self.samples[idx]
        x = domain_to_tensor(dom)
        return x, lbl

# %%
import pandas as pd 
data = pd.read_pickle('/home/dung/Downloads/Model/test/domain2/benign_test.pkl')
print(dir(data) ) 
print(type(data) )
print(len(data))

obj = data 
print(type(obj.samples))
print(len(obj.samples))

# xem 5 phần tử đầu tiên
for i in range(5):
    print("\n--- sample", i, "---")
    print(obj.samples[i])
    print("type:", type(obj.samples[i]))
# Out:
# ['__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_is_protocol', 'samples']
# <class '__main__.DomainDataset'>
# 200000
# <class 'list'>
# 200000
#
# --- sample 0 ---
# ('callcontroller.swce-02.ic3-calling-callcontroller.swedencentral-prod.cosmic.office.net', 0)
# type: <class 'tuple'>
#
# --- sample 1 ---
# ('a407.d.akamai.net', 0)
# type: <class 'tuple'>
#
# --- sample 2 ---
# ('n4i6g1.akamai.net', 0)
# type: <class 'tuple'>
#
# --- sample 3 ---
# ('mxb-0005f601.gslb.pphosted.com', 0)
# type: <class 'tuple'>
#
# --- sample 4 ---
# ('log-upload.mihoyo.com', 0)
# type: <class 'tuple'>

# %%
print(type(obj.samples))
print(len(obj.samples))

# xem 5 phần tử đầu tiên
for i in range(100):
    print("\n--- sample", i, "---")
    print(obj.samples[i])
    print("type:", type(obj.samples[i]))
# Out:
# <class 'list'>
# 200000
#
# --- sample 0 ---
# ('callcontroller.swce-02.ic3-calling-callcontroller.swedencentral-prod.cosmic.office.net', 0)
# type: <class 'tuple'>
#
# --- sample 1 ---
# ('a407.d.akamai.net', 0)
# type: <class 'tuple'>
#
# --- sample 2 ---
# ('n4i6g1.akamai.net', 0)
# type: <class 'tuple'>
#
# --- sample 3 ---
# ('mxb-0005f601.gslb.pphosted.com', 0)
# type: <class 'tuple'>
#
# --- sample 4 ---
# ('log-upload.mihoyo.com', 0)
# type: <class 'tuple'>
#
# --- sample 5 ---
# ('symplr.webex.com', 0)
# type: <class 'tuple'>
#
# --- sample 6 ---
# ('dc.grabit.video', 0)
# type: <class 'tuple'>
#
# --- sample 7 ---
# ('oyoroomscdn.com', 0)
# type: <class 'tuple'>
#
# --- sample 8 ---
# ('eu-central-1.fortianalyzer.forticloud.com', 0)
# type: <class 'tuple'>
#
# --- sample 9 ---
# ('mon.tiktokv.com.www.tendawifi.com', 0)
# type: <class 'tuple'>
#
# --- sample 10 ---
# ('labelary.com', 0)
# type: <class 'tuple'>
#
# --- sample 11 ---
# ('wip.uhc.com', 0)
# type: <class 'tuple'>
#
# --- sample 12 ---
# ('data.mocreo.com', 0)
# type: <class 'tuple'>
#
# --- sample 13 ---
# ('cbz.elb.myaffiliates.com', 0)
# type: <class 'tuple'>
#
# --- sample 14 ---
# ('weblondonlobal.kiosk-webaccess-insolarisernomaps-whmsrv-fsolarisp.srv.srv.blinkist.com', 0)
# type: <class 'tuple'>
#
# --- sample 15 ---
# ('thunderbike.com', 0)
# type: <class 'tuple'>
#
# --- sample 16 ---
# ('analytics.omniscientai.com', 0)
# type: <class 'tuple'>
#
# --- sample 17 ---
# ('mx1.mta-sts.mx1.tpcameron.com', 0)
# type: <class 'tuple'>
#
# --- sample 18 ---
# ('j0604011.vps18.u.avcdn.net', 0)
# type: <class 'tuple'>
#
# --- sample 19 ---
# ('rr2---sn-gxuo03g-3c2e.googlevideo.com', 0)
# type: <class 'tuple'>
#
# --- sample 20 ---
# ('rr1---sn-8xgn5uxa-quhs.googlevideo.com', 0)
# type: <class 'tuple'>
#
# --- sample 21 ---
# ('mxa-001ffb01.gslb.pphosted.com', 0)
# type: <class 'tuple'>
#
# --- sample 22 ---
# ('practiscore.com', 0)
# type: <class 'tuple'>
#
# --- sample 23 ---
# ('avisportal.duvenbeck.de', 0)
# type: <class 'tuple'>
#
# --- sample 24 ---
# ('ns-424.awsdns-53.com', 0)
# type: <class 'tuple'>
#
# --- sample 25 ---
# ('advisorgroup.svc.snapcomms.com', 0)
# type: <class 'tuple'>
#
# --- sample 26 ---
# ('primedia.primark.com', 0)
# type: <class 'tuple'>
#
# --- sample 27 ---
# ('zn1h79mkvfpye4j1q-idme.siteintercept.qualtrics.com', 0)
# type: <class 'tuple'>
#
# --- sample 28 ---
# ('sonar.fhan5-9.fna.fbcdn.net', 0)
# type: <class 'tuple'>
#
# --- sample 29 ---
# ('27.xg4ken.com', 0)
# type: <class 'tuple'>
#
# --- sample 30 ---
# ('thunder-development.com', 0)
# type: <class 'tuple'>
#
# --- sample 31 ---
# ('s.everestop.io', 0)
# type: <class 'tuple'>
#
# --- sample 32 ---
# ('194519-ipv4v6e.farm.dprodmgd105.aa-rt.sharepoint.com', 0)
# type: <class 'tuple'>
#
# --- sample 33 ---
# ('12572385.fls.doubleclick.net', 0)
# type: <class 'tuple'>
#
# --- sample 34 ---
# ('as.gree.com', 0)
# type: <class 'tuple'>
#
# --- sample 35 ---
# ('p.potaufeu.asahi.com', 0)
# type: <class 'tuple'>
#
# --- sample 36 ---
# ('metrics.civitatis.com', 0)
# type: <class 'tuple'>
#
# --- sample 37 ---
# ('5ln1h5525y2q.kentut.xyz', 0)
# type: <class 'tuple'>
#
# --- sample 38 ---
# ('www.fhfa.gov', 0)
# type: <class 'tuple'>
#
# --- sample 39 ---
# ('translations.deriv.com', 0)
# type: <class 'tuple'>
#
# --- sample 40 ---
# ('transact-tech.com', 0)
# type: <class 'tuple'>
#
# --- sample 41 ---
# ('mx16c.antispameurope.com', 0)
# type: <class 'tuple'>
#
# --- sample 42 ---
# ('media.cbs8.com', 0)
# type: <class 'tuple'>
#
# --- sample 43 ---
# ('newoneinoldoneout.pro', 0)
# type: <class 'tuple'>
#
# --- sample 44 ---
# ('beamlongestneffllc-my.sharepoint.com', 0)
# type: <class 'tuple'>
#
# --- sample 45 ---
# ('forum.ixbt.com', 0)
# type: <class 'tuple'>
#
# --- sample 46 ---
# ('rabobank.co.nz', 0)
# type: <class 'tuple'>
#
# --- sample 47 ---
# ('merchantlogos.net', 0)
# type: <class 'tuple'>
#
# --- sample 48 ---
# ('a446.t.akamai.net', 0)
# type: <class 'tuple'>
#
# --- sample 49 ---
# ('cspire.com', 0)
# type: <class 'tuple'>
#
# --- sample 50 ---
# ('merchantgould-my.sharepoint.com', 0)
# type: <class 'tuple'>
#
# --- sample 51 ---
# ('my.xchat.life', 0)
# type: <class 'tuple'>
#
# --- sample 52 ---
# ('mx1.mx1.mta-sts.mx1.mail.occcustomsite7.com', 0)
# type: <class 'tuple'>
#
# --- sample 53 ---
# ('7idr3.com', 0)
# type: <class 'tuple'>
#
# --- sample 54 ---
# ('prod5.dtp.dynatrace.com', 0)
# type: <class 'tuple'>
#
# --- sample 55 ---
# ('prod.ba2.netease.com', 0)
# type: <class 'tuple'>
#
# --- sample 56 ---
# ('presence.gov.teams.usgovtrafficmanager.net', 0)
# type: <class 'tuple'>
#
# --- sample 57 ---
# ('subroiq.s3.us-east-2.amazonaws.com', 0)
# type: <class 'tuple'>
#
# --- sample 58 ---
# ('o889482.ingest.sentry.io', 0)
# type: <class 'tuple'>
#
# --- sample 59 ---
# ('rr3.sn-cvb7sn7r.googlevideo.com', 0)
# type: <class 'tuple'>
#
# --- sample 60 ---
# ('nikke-jp.com', 0)
# type: <class 'tuple'>
#
# --- sample 61 ---
# ('api.tiket.com', 0)
# type: <class 'tuple'>
#
# --- sample 62 ---
# ('suitableanswers.com', 0)
# type: <class 'tuple'>
#
# --- sample 63 ---
# ('rr2---sn-uhvcpax0n5-qufz.googlevideo.com', 0)
# type: <class 'tuple'>
#
# --- sample 64 ---
# ('server15.cdneurops.pics', 0)
# type: <class 'tuple'>
#
# --- sample 65 ---
# ('rotator-prod-oh-acai-lb.inbake.com', 0)
# type: <class 'tuple'>
#
# --- sample 66 ---
# ('0.o.0.cdn-node.ss.one.04.gmaes-cdn-usercontent.com', 0)
# type: <class 'tuple'>
#
# --- sample 67 ---
# ('iprism.co.uk', 0)
# type: <class 'tuple'>
#
# --- sample 68 ---
# ('maps.columbus.gov', 0)
# type: <class 'tuple'>
#
# --- sample 69 ---
# ('nuxt.fstatic.nl', 0)
# type: <class 'tuple'>
#
# --- sample 70 ---
# ('s-imp.rmp.rakuten.com', 0)
# type: <class 'tuple'>
#
# --- sample 71 ---
# ('veryfitproapi.veryfitplus.com', 0)
# type: <class 'tuple'>
#
# --- sample 72 ---
# ('a-govtx-01.conv.gov.teams.microsoft.us', 0)
# type: <class 'tuple'>
#
# --- sample 73 ---
# ('sydney-lb.geo.iponweb.net', 0)
# type: <class 'tuple'>
#
# --- sample 74 ---
# ('rr3---sn-pivhx-n8vl.googlevideo.com', 0)
# type: <class 'tuple'>
#
# --- sample 75 ---
# ('catapultsports.com', 0)
# type: <class 'tuple'>
#
# --- sample 76 ---
# ('sign-service.signcommand.com', 0)
# type: <class 'tuple'>
#
# --- sample 77 ---
# ('api.eu1.app.liongard.com', 0)
# type: <class 'tuple'>
#
# --- sample 78 ---
# ('www.locumtenens.com', 0)
# type: <class 'tuple'>
#
# --- sample 79 ---
# ('151.docs.google.com', 0)
# type: <class 'tuple'>
#
# --- sample 80 ---
# ('rr3---sn-vgqsknze.gvt1.com', 0)
# type: <class 'tuple'>
#
# --- sample 81 ---
# ('mongodb.email.cs.money', 0)
# type: <class 'tuple'>
#
# --- sample 82 ---
# ('aspor.com.tr', 0)
# type: <class 'tuple'>
#
# --- sample 83 ---
# ('unitedwifi.com.edgekey.net', 0)
# type: <class 'tuple'>
#
# --- sample 84 ---
# ('media.fsap10-1.fna.whatsapp.net', 0)
# type: <class 'tuple'>
#
# --- sample 85 ---
# ('ethos503-prod-va6-k8s-p2-0-ce09078037a86341.elb.us-east-1.amazonaws.com', 0)
# type: <class 'tuple'>
#
# --- sample 86 ---
# ('1970sfilmstock.bandcamp.com', 0)
# type: <class 'tuple'>
#
# --- sample 87 ---
# ('sn-8qj-i5ol7.googlevideo.com', 0)
# type: <class 'tuple'>
#
# --- sample 88 ---
# ('opsdjs.ug', 0)
# type: <class 'tuple'>
#
# --- sample 89 ---
# ('carelink.hopkinsmedicine.org', 0)
# type: <class 'tuple'>
#
# --- sample 90 ---
# ('pro-article-context-694432520.eu-west-1.elb.amazonaws.com', 0)
# type: <class 'tuple'>
#
# --- sample 91 ---
# ('book-bff.savvasrealize.com', 0)
# type: <class 'tuple'>
#
# --- sample 92 ---
# ('epic.appliedepic.com', 0)
# type: <class 'tuple'>
#
# --- sample 93 ---
# ('customer-1tlorv0cm1pl7e9c.cloudflarestream.com', 0)
# type: <class 'tuple'>
#
# --- sample 94 ---
# ('r3.sn-a5mekn6d.googlevideo.com', 0)
# type: <class 'tuple'>
#
# --- sample 95 ---
# ('creative-accelerate.ad.mobiuspace.net', 0)
# type: <class 'tuple'>
#
# --- sample 96 ---
# ('ms.cms.staging.kinder.com', 0)
# type: <class 'tuple'>
#
# --- sample 97 ---
# ('market.qa03.dba.dk', 0)
# type: <class 'tuple'>
#
# --- sample 98 ---
# ('prod-search-api.jobsyn.org', 0)
# type: <class 'tuple'>
#
# --- sample 99 ---
# ('collisionbendbrewery.com', 0)
# type: <class 'tuple'>

# %%
class BiLSTMClassifier(nn.Module):
    def __init__(self, vocab_size=vocab_size, embed_dim=32, hidden_dim=64, num_classes=2, dropout=0.5):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.bilstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.attention = nn.Linear(hidden_dim * 2, 1)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim * 2, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(dropout),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        emb = self.embedding(x)  # (batch_size, seq_len, embed_dim)
        bilstm_out, _ = self.bilstm(emb)  # (batch_size, seq_len, hidden_dim*2)

        # Attention Mechanism
        attn_weights = F.softmax(self.attention(bilstm_out).squeeze(2), dim=1)  # (batch_size, seq_len)
        attn_output = torch.bmm(attn_weights.unsqueeze(1), bilstm_out).squeeze(1)  # (batch_size, hidden_dim*2)

        attn_output = self.dropout(attn_output)
        logits = self.fc(attn_output)
        return logits

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
    benign_train_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/benign_train.pkl")
    benign_test_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/benign_test.pkl")
    dga_1_train_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_1_train.pkl")
    dga_1_test_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_1_test.pkl")
    dga_2_train_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_2_train.pkl")
    dga_2_test_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_2_test.pkl")
    dga_3_train_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_3_train.pkl")
    dga_3_test_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_3_test.pkl")
    dga_4_train_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_4_train.pkl")
    dga_4_test_ds = load_dataset("/home/dung/Downloads/Model/test/domain2/dga_4_test.pkl")

    train_ds = ConcatDataset([benign_train_ds, dga_1_train_ds, dga_2_train_ds, dga_3_train_ds, dga_4_train_ds])
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

    test_ds = ConcatDataset([benign_test_ds, dga_1_test_ds, dga_2_test_ds, dga_3_test_ds, dga_4_test_ds])
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    model = BiLSTMClassifier().to(device)
    criterion = nn.CrossEntropyLoss()

    optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
# Out:
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/benign_train.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/benign_test.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_1_train.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_1_test.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_2_train.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_2_test.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_3_train.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_3_test.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_4_train.pkl.
# DataLoader loaded from /home/dung/Downloads/Model/test/domain2/dga_4_test.pkl.

# %%
def train_client(model, client_loader, criterion, optimizer):
    model.train()
    for x_batch, y_batch in tqdm(client_loader):
        if x_batch.size(0) == 1:
            continue
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        logits = model(x_batch)
        loss = criterion(logits, y_batch)
        loss.backward()
        optimizer.step()


def test_model(model, test_loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            logits = model(x_batch)
            preds = logits.argmax(dim=1)

            all_preds.extend(preds.cpu().numpy().flatten())
            all_labels.extend(y_batch.cpu().numpy().flatten())

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, zero_division=0)
    recall = recall_score(all_labels, all_preds, zero_division=0)
    f1 = f1_score(all_labels, all_preds, zero_division=0)

    return f"Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}"

# %%
for _ in range(num_epochs):
        train_client(model, train_loader, criterion, optimizer)
        result = test_model(model, test_loader)
        print(result)
# Out:
# 100%|██████████| 49660/49660 [01:44<00:00, 475.25it/s]
# Accuracy: 0.8658, Precision: 0.8379, Recall: 0.9047, F1-score: 0.8700
# 100%|██████████| 49660/49660 [01:51<00:00, 447.26it/s]
# Accuracy: 0.8946, Precision: 0.8541, Recall: 0.9502, F1-score: 0.8996
# 100%|██████████| 49660/49660 [01:45<00:00, 470.91it/s]
# Accuracy: 0.9096, Precision: 0.8751, Recall: 0.9542, F1-score: 0.9129
# 100%|██████████| 49660/49660 [01:45<00:00, 469.32it/s]
# Accuracy: 0.9217, Precision: 0.9004, Recall: 0.9471, F1-score: 0.9232
# 100%|██████████| 49660/49660 [01:44<00:00, 473.06it/s]
# Accuracy: 0.9252, Precision: 0.8860, Recall: 0.9748, F1-score: 0.9283
# 100%|██████████| 49660/49660 [01:41<00:00, 487.39it/s]
# Accuracy: 0.9299, Precision: 0.8943, Recall: 0.9740, F1-score: 0.9325
# 100%|██████████| 49660/49660 [01:46<00:00, 466.68it/s]
# Accuracy: 0.9335, Precision: 0.8996, Recall: 0.9748, F1-score: 0.9357
# 100%|██████████| 49660/49660 [01:49<00:00, 455.17it/s]
# Accuracy: 0.9383, Precision: 0.9199, Recall: 0.9593, F1-score: 0.9391
# 100%|██████████| 49660/49660 [01:52<00:00, 442.39it/s]
# Accuracy: 0.9411, Precision: 0.9226, Recall: 0.9622, F1-score: 0.9420
# 100%|██████████| 49660/49660 [01:49<00:00, 454.28it/s]
# Accuracy: 0.9396, Precision: 0.9081, Recall: 0.9772, F1-score: 0.9414

# %%
train_ds.samples
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 train_ds.samples
#
# NameError: name 'train_ds' is not defined
